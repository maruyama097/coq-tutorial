# %% [markdown]
# # 論理式の証明

# %% [markdown]
# ## 演習問題
# #### 演習問題 1-1
# <a id="ex1-1" ></a>
# 次の定理を証明せよ。
#  <font color="blue"　size="4" >Theorem my_first_proof : (forall A : Prop, A -> A).</font>
# <br>
# [作業用ページで証明をして見る](./samples/work/ex01.ipynb)　/ [ヒントを見る](./samples/hints/ex01.ipynb ) / [解答を見る](./samples/answers/ex01.ipynb) / [演習問題に戻る](../../Logic-Ex.ipynb )
